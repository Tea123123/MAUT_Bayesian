# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
def us(c_list,a): #utility function for the list of values
    if a == 0:
        return c_list
    else:        
        return [u(c, a) for c in c_list]

# %%
def u(x,a,s):
    if a == 0:
        return (1/6*s)*x + 0.5
    else: 
        def b(x):
            return 1-math.e**(-a*x)
        return (b(x)-b(-3*s))/(b(3*s)-b(-3*s))
    
def us(x_list, a, s): #utility function for the list of values           
    return [u(x, a, s) for x in x_list]

# %%
u_list = np.random.normal(0,1,1000)

# %%
X = np.arange(-3,3,0.05)
Y1 = [u(x,0.367,1) for x in X]
Y2 = [u(x,-0.367,1) for x in X]
Y3 = [u(x,0,1) for x in X] 
plt.plot(X,Y3, label='linear') 
plt.plot(X,Y1, label='concave') 
plt.plot(X,Y2, label='convex') 
plt.axvline(0, color='k')
plt.axhline(0, color='k')

import matplotlib.ticker as plticker


plt.yticks(np.arange(-.25, 1.25, 0.25))

plt.grid(which='major', axis='both', linestyle='-')
plt.legend()

# %% [markdown]
# ## Selection Bias - single attribute

# %%
def cal_post(m, mu=0, s=1, t=1, a=0):
    d_list = []
    for i in range(10000):
        #Generate $m$ true values $x_j$ from the prior
        x = np.random.normal(mu,s,m) #x_j~N(0,1)
        u_x = us(x, a, s)
        
        #For each true value, generate an estimate $y_j$ from the likelihood 
        y = [np.random.normal(x_j,t,1)[0] for x_j in x] #y_j~N(x_j,1)
        u_y = us(y, a, s)
        
        max_uy = max(u_y)
        max_j = u_y.index(max_uy)
        
        #posterior disappointment 
        d = (u_x[max_j] - max_uy)/max_uy
        
        d_list.append(d)
    #Compute the difference $u(x_\tilde{j})-\sum_{k=1}^1000 u_(x_\tilde{j}k)$
    return d_list

# %%
d = {}
for m in [2,3,5,10]:
    d[m] = cal_post(m, a=0)
    
df = pd.DataFrame(d)
df.boxplot(showmeans=True)
plt.show()
print(df.mean(axis=0))
# Out:
# 2    -0.058067
# 3    -0.110592
# 5    -0.157807
# 10   -0.203589
# dtype: float64

# %%
d = {}
for m in [2,3,5,10]:
    d[m] = cal_post(m, a=0.367)
    
df = pd.DataFrame(d)
df.boxplot(showmeans=True)
plt.show()
print(df.mean(axis=0))
# Out:
# 2    -0.027690
# 3    -0.061255
# 5    -0.079187
# 10   -0.090663
# dtype: float64

# %%
d = {}
for m in [2,3,5,10]:
    d[m] = cal_post(m, a=-0.367)
    
df = pd.DataFrame(d)
df.boxplot(showmeans=True)
plt.show()
print(df.mean(axis=0))
# Out:
# 2    -0.055104
# 3    -0.173536
# 5    -0.268038
# 10   -0.348955
# dtype: float64

# %% [markdown]
# ## Selection Bias - multi attribute

# %%
def cal_post_mu(m=5, mu=[0,0,0], s=[1,1,1], t=[1,1,1], w=[1/3, 1/3, 1/3], a=[0,0,0]):
    
    def cal_u(multiatt):
        ul = [u(multiatt[i], a[i], 1) for i in range(len(multiatt))]
        return np.dot(w, ul)
    
    d_list = []
    for k in range(1000):
        x = []
        eu = []
        
        for j in range(m): #loop for generating mu alternatives
            
            n = len(mu) #number of attributes
            x_j = [np.random.normal(mu[i], s[i],1)[0] for i in range(n)] #generate true mu of one alternative
            x.append(cal_u(x_j)) #append the utility of one mu alternative u(x_j)
            
            y_j = [np.random.normal(x_j[i], t[i],1)[0] for i in range(n)] #generate estimated mu of one alternative
            
            eu.append(cal_u(y_j)) #append the utility of one mu estimates u(y_j)

        #Choose the alternative $j^$ with the highest expected utility
        max_eu = max(eu)
        max_j = eu.index(max_eu)

        #posterior disappointment 
        d = (x[max_j] - max_eu)/max_eu
        d_list.append(d)
        #Compute the difference $u(x_\tilde{j})-\sum_{k=1}^1000 u_(x_\tilde{j}k)$
    return d_list

# %% [markdown]
# # Varying number of alternatives

# %%
d = {}
for m in [2,3,5,10]:
    d[m] = cal_post_mu(m=m)
    
df = pd.DataFrame(d)
df.boxplot(showmeans=True)
plt.show()
print(df.mean(axis=0))
# Out:
# 2    -0.054068
# 3    -0.079436
# 5    -0.116094
# 10   -0.146299
# dtype: float64

# %%
d = {}
for m in [2,3,5,10]:
    d[m] = cal_post_mu(m=m, a = [0.367]*3)
    
df = pd.DataFrame(d)
df.boxplot(showmeans=True)
plt.show()
print(df.mean(axis=0))
# Out:
# 2    -0.011065
# 3    -0.031497
# 5    -0.050285
# 10   -0.063209
# dtype: float64

# %%
d = {}
for m in [2,3,5,10]:
    d[m] = cal_post_mu(m=m, a = [-0.367]*3)
    
df = pd.DataFrame(d)
df.boxplot(showmeans=True)
plt.show()
print(df.mean(axis=0))
# Out:
# 2    -0.128894
# 3    -0.182448
# 5    -0.241250
# 10   -0.289587
# dtype: float64

# %% [markdown]
# # varying number of attributes

# %%
d = {}
for n in [2,3,5,10]:
    d[n] = cal_post_mu(m=5, mu=[0]*n,s=[1]*n, t=[1]*n, w=[1/n]*n, a=[0]*n )
    
df = pd.DataFrame(d)
df.boxplot(showmeans=True)
plt.show()
print(df.mean(axis=0))
# Out:
# 2    -0.128096
# 3    -0.116809
# 5    -0.090628
# 10   -0.071066
# dtype: float64

# %%
d = {}
for n in [2,3,5,10]:
    d[n] = cal_post_mu(m=5, mu=[0]*n,s=[1]*n, t=[1]*n, w=[1/n]*n, a=[0.367]*n )
    
df = pd.DataFrame(d)
df.boxplot(showmeans=True)
plt.show()
print(df.mean(axis=0))
# Out:
# 2    -0.057705
# 3    -0.052986
# 5    -0.037394
# 10   -0.019253
# dtype: float64

# %%
d = {}
for n in [2,3,5,10]:
    d[n] = cal_post_mu(m=5, mu=[0]*n,s=[1]*n, t=[1]*n, w=[1/n]*n, a=[-0.367]*n )
    
df = pd.DataFrame(d)
df.boxplot(showmeans=True)
plt.show()
print(df.mean(axis=0))
# Out:
# 2    -0.248979
# 3    -0.233396
# 5    -0.222820
# 10   -0.201137
# dtype: float64

# %% [markdown]
# # Varying criterion-specific uncertainty

# %%
def cal_post_mu(m=5, mu=[0,0,0], s=[1,1,1], t=[1,1,1], w=[1/3, 1/3, 1/3], a=[0,0,0]):
    
    def cal_u(multiatt):
        ul = [u(multiatt[i], a[i], 1) for i in range(len(multiatt))]
        return np.dot(w, ul)
    
    d_list = []
    d_mu_list = []
    for k in range(1):
        x = []
        eu = []
        
        mx = []
        meu = []
        for j in range(m): #loop for generating mu alternatives
            
            n = len(mu) #number of attributes
            x_j = [np.random.normal(mu[i], s[i],1)[0] for i in range(n)] #generate true mu of one alternative
            print("x_j", x_j)
            x.append(cal_u(x_j)) #append the utility of one mu alternative u(x_j)           
            ux_j= np.array(us(x_j, a, 1)) #utilities of individual attributes
            mx.append(ux_j)
            
            y_j = [np.random.normal(x_j[i], t[i],1)[0] for i in range(n)] #generate estimated mu of one alternative            
            print("y_j", y_j)
            eu.append(cal_u(y_j)) #append the utility of one mu estimates u(y_j)
            uy_j = us(y_j, a, 1) #utilities of individual attributes
            meu.append(uy_j)
            
        #Choose the alternative $j^$ with the highest expected utility
        max_eu = max(eu)
        max_j = eu.index(max_eu)

        #disappointment 
        d = (x[max_j] - max_eu)/max_eu
        d_mu = (mx[max_j]-meu[max_j])/meu[max_j]
        d_list.append(d)
        d_mu_list.append(d_mu)
        #Compute the difference $u(x_\tilde{j})-\sum_{k=1}^1000 u_(x_\tilde{j}k)$
    return d_list, d_mu_list

# %%
(np.array([1,2,3])-np.array([0,1,1]))/np.array([2,2,2])
# Out:
# array([0.5, 0.5, 1. ])

# %%
cal_post_mu()
# Out:
# x_j [1.097035379100628, -0.021773403969550388, -2.1474416260124647]
# y_j [0.24178703400223556, -0.2605281424436227, -4.075848396016681]
# x_j [-1.72179474272934, 1.395646436959494, -1.4023400697826192]
# y_j [-2.353794481548233, 1.906619519160282, 0.13178097912815212]
# x_j [-0.7530790525389045, 0.9811427807776238, 2.0549496600973587]
# y_j [-1.0759931923157098, 0.9248127907035, 0.3181382692111414]
# x_j [1.8045759628159852, -2.0948983934438785, -0.6351610101885292]
# y_j [0.5860325673146698, -0.8689329029119193, -1.778305256250061]
# x_j [-1.2430889977709083, -0.06594913705982679, -0.9969565568596965]
# y_j [-2.48022394255249, 0.6156431755422894, 0.02362324235191915]
# [0.23083508741939884]

# %%
def mu_list(n_attribute, weights, n_alternatives, a=0):
    mu_list = [] #list of multiattribute utility
    
    for i in range(n_alternatives):
        u = us(np.random.normal(0,1,n_attribute), a) #list of attribute-specific utilities
        #append the weighted sum of multiattribute utilities 
        mu_list.append(sum([x*y for x, y in zip(u, weights)])) 
        
    return mu_list #list of alternatives

# %% [markdown]
# 2-attribute, linear utility function

# %%
x = np.array([1,2,3])
y = np.array([0.5, 0.5, 0.5])

[(x,y) for x,y in zip(x,y)]
# Out:
# [(1, 0.5), (2, 0.5), (3, 0.5)]

# %%
max_df = {}
for n in range(1,16):
    max_list = []
    for i in range(1000): #simulate 1000 times
        max_list.append(max(mu_list(2, np.array([0.5, 0.5]), n)))
    max_df[n] = max_list
    
    
df = pd.DataFrame(max_df)
print(df.mean(axis=0))

sns.kdeplot(df[1])
sns.kdeplot(df[2])
sns.kdeplot(df[5])
sns.kdeplot(df[10])
# Out:
# 1    -0.009720
# 2     0.341860
# 3     0.611625
# 4     0.768437
# 5     0.808768
# 6     0.888130
# 7     0.946447
# 8     1.001033
# 9     1.037232
# 10    1.082004
# 11    1.112612
# 12    1.133470
# 13    1.177469
# 14    1.193115
# 15    1.224551
# dtype: float64

# %%
def mu_mean_bias(n_attributes, weights, a):
    
    max_df = {}
    for n in range(1,16):
        max_list = []
        for i in range(1000): #simulate 1000 times
            max_list.append(max(mu_list(n_attributes, weights, n, a)))
        max_df[n] = max_list


    df = pd.DataFrame(max_df)
    print(df.mean(axis=0))

    sns.kdeplot(df[1])
    sns.kdeplot(df[2])
    sns.kdeplot(df[5])
    sns.kdeplot(df[10])

# %%
mu_mean_bias(2, np.array([0.5, 0.5]), 0)
# Out:
# 1     0.002501
# 2     0.393991
# 3     0.598260
# 4     0.739466
# 5     0.812578
# 6     0.910672
# 7     0.953961
# 8     1.006790
# 9     1.050033
# 10    1.089759
# 11    1.119157
# 12    1.152867
# 13    1.179027
# 14    1.199008
# 15    1.216559
# dtype: float64

# %%
mu_mean_bias(3, np.array([1/3, 1/3, 1/3]), 0) #3-attribute, linear
# Out:
# 1    -0.023418
# 2     0.320423
# 3     0.499116
# 4     0.585872
# 5     0.672125
# 6     0.744954
# 7     0.793194
# 8     0.821202
# 9     0.857135
# 10    0.890735
# 11    0.915138
# 12    0.952142
# 13    0.944402
# 14    0.997269
# 15    1.011410
# dtype: float64

# %%
mu_mean_bias(5, np.array([1/5, 1/5, 1/5, 1/5, 1/5]), 0) #3-attribute, linear
# Out:
# 1     0.005977
# 2     0.233638
# 3     0.382158
# 4     0.443468
# 5     0.519470
# 6     0.561333
# 7     0.598819
# 8     0.648077
# 9     0.652736
# 10    0.685296
# 11    0.705330
# 12    0.736181
# 13    0.745373
# 14    0.762159
# 15    0.772524
# dtype: float64

# %%
mu_mean_bias(3, np.array([0.2, 0.7, 0.1]), 0) #3-attribute, linear
# Out:
# 1     0.017224
# 2     0.414522
# 3     0.635059
# 4     0.767927
# 5     0.851233
# 6     0.914550
# 7     1.003178
# 8     1.039844
# 9     1.089241
# 10    1.140437
# 11    1.164257
# 12    1.185659
# 13    1.218412
# 14    1.251535
# 15    1.283806
# dtype: float64

# %%
mu_mean_bias(3, np.array([1/3, 1/3, 1/3]), 0.5) #3-attribute, concave
# Out:
# 1    -0.255625
# 2     0.106432
# 3     0.266277
# 4     0.374213
# 5     0.441897
# 6     0.492166
# 7     0.522446
# 8     0.551775
# 9     0.577815
# 10    0.608019
# 11    0.634553
# 12    0.640896
# 13    0.670609
# 14    0.680723
# 15    0.695029
# dtype: float64

# %%
mu_mean_bias(3, np.array([1/3, 1/3, 1/3]), -0.5) #3-attribute, convex
# Out:
# 1     0.240088
# 2     0.673478
# 3     0.855210
# 4     1.027698
# 5     1.138920
# 6     1.237822
# 7     1.340558
# 8     1.392290
# 9     1.409120
# 10    1.520157
# 11    1.526985
# 12    1.578042
# 13    1.632764
# 14    1.680374
# 15    1.699118
# dtype: float64
